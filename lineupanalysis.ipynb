# %%
import pandas as pd

# %%
df = pd.read_json("lineupdata.json").values.tolist()
df2 = []

# %%
for i in df:
    for j in i:
        df2.append(j)

# %%
df = pd.DataFrame(df2)

# %%
df
# Out:
#            0                                          1
# 0     Lineups     -202689-203493-203501-1626174-1627827-  \
# 1     Lineups    -203484-203999-1629008-1630192-1630538-
# 2     Lineups   -201599-1628427-1628971-1629008-1631128-
# 3     Lineups      -201566-201569-202331-202694-1627826-
# 4     Lineups    -201599-202704-1628971-1631128-1631212-
# ...       ...                                        ...
# 1995  Lineups    -201950-203507-1626171-1626192-1628960-
# 1996  Lineups   -203944-1628973-1629628-1629656-1630193-
# 1997  Lineups  -1626168-1627734-1628368-1628370-1631099-
# 1998  Lineups   -204456-1626167-1629614-1630174-1631097-
# 1999  Lineups   -203084-1627734-1628368-1630558-1631099-
#
#                                                      2           3    4   5
# 0     K. Walker - R. Bullock - T. Hardaway Jr. - C. ...  1610612742  DAL   1  \
# 1     K. Caldwell-Pope - N. Jokic - M. Porter Jr. - ...  1610612743  DEN   1
# ...

# %%
df = df.set_axis(["GROUP_SET", "GROUP_ID", "GROUP_NAME", "TEAM_ID", "TEAM_ABBR", "GP", "W", "L", "W_PCT", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "TOV", "STL", "BLK", "BLKA", "PF", "PFD", "Points", "PlusMinus", "GP_RANK", "W_RANK", "L_RANK", "W_PCT_RANK", "MIN_RANK", "FGM_RANK", "FGA_RANK", "FG_PCT_RANK", "FG3M_RANK", "FG3A_RANK", "FG3_PCT_RANK", "FTM_RANK", "FTA_RANK", "FT_PCT_RANK", "OREB_RANK", "DREB_RANK", "REB_RANK", "AST_RANK","TOV_RANK", "STL_RANK", "BLK_RANK", "BLKA_RANK", "PF_RANK", "PFD_RANK", "PTS_RANK", "PLUS_MINUS_RANK"], axis=1)

# %%
df = pd.DataFrame(df[['GROUP_NAME', "PlusMinus"]])

# %%
df.to_csv("cleanedlineup.csv")
